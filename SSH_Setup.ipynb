# %% [markdown]
# # 🚀 SSH Tunnel Setup
# Run this cell to generate your SSH Connection Command.
# **Note:** You must run this in your Browser (Chrome/Edge) at `colab.research.google.com` to ensure the connection stays alive.

# %%
# 1. Install & Launch Tunnel
# !pip install colab_ssh --upgrade &> /dev/null
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared

# Set your password here (default: '1234')
PASSWORD = "1234"

print("☁️ Starting SSH Tunnel... (Wait 10-20s)")
launch_ssh_cloudflared(password=PASSWORD)

print("\n✅ DONE! Copy the command below (starting with 'Host google_colab...')")
print("Then paste it into your VS Code SSH Config file.")
